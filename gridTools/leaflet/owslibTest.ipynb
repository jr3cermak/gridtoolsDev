# %%
#conda: legacyTools

from owslib.wms import WebMapService

# %%
wms = WebMapService('https://tigerweb.geo.census.gov/arcgis/services/TIGERweb/tigerWMS_Current/MapServer/WMSServer',
                    version='1.1.1')
print(wms.identification.type)
print(wms.identification.version)
print(wms.identification.title)
print(wms.identification.abstract)
# Out:
# WMS
# 1.1.1
# OGC:WMS
# OGC:WMS

# %%
list(wms.contents)
# Out:
# ['Counties Labels',
#  'Counties',
#  'States Labels',
#  'States',
#  'Micropolitan Statistical Areas Labels',
#  'Micropolitan Statistical Areas',
#  'Metropolitan Statistical Areas Labels',
#  'Metropolitan Statistical Areas',
#  'Metropolitan Divisions Labels',
#  'Metropolitan Divisions',
#  'Combined Statistical Areas Labels',
#  'Combined Statistical Areas',
#  'Micropolitan New England City and Town Areas Labels',
#  'Micropolitan New England City and Town Areas',
#  'Metropolitan New England City and Town Areas Labels',
#  'Metropolitan New England City and Town Areas',
#  'New England City and Town Area  Divisions Labels',
#  'New England City and Town Area Divisions',
#  'Combined New England City and Town Areas Labels',
#  'Combined New England City and Town Areas',
#  '2010 Census Urban Clusters Labels',
#  '2010 Census Urban Clusters',
#  '2010 Census Urbanized Areas Labels',
#  '2010 Census Urbanized Areas',
#  'Census Regions Labels',
#  'Census Regions',
#  'Census Divisions Labels',
#  'Census Divisions',
#  '2018 State Legislative Districts - Lower Labels',
#  '2018 State Legislative Districts - Lower',
#  '2018 State Legislative Districts - Upper Labels',
#  '2018 State Legislative Districts - Upper',
#  '116th Congressional Districts Labels',
#  '116th Congressional Districts',
#  'American Indian Joint-Use Areas Labels',
#  'American Indian Joint-Use Areas',
#  'Tribal Designated Statistical Areas Labels',
#  'Tribal Designated Statistical Areas',
#  'State Designated Tribal Statistical Areas Labels',
#  'State Designated Tribal Statistical Areas',
#  'Oklahoma Tribal Statistical Areas Labels',
#  'Oklahoma Tribal Statistical Areas',
#  'Alaska Native Village Statistical Areas Labels',
#  'Alaska Native Village Statistical Areas',
#  'Hawaiian Home Lands Labels',
#  'Hawaiian Home Lands',
#  'State American Indian Reservations Labels',
#  'State American Indian Reservations',
#  'Off-Reservation Trust Lands Labels',
#  'Off-Reservation Trust Lands',
#  'Federal American Indian Reservations Labels',
#  'Federal American Indian Reservations',
#  'Tribal Subdivisions Labels',
#  'Tribal Subdivisions',
#  'Alaska Native Regional Corporations Labels',
#  'Alaska Native Regional Corporations',
#  'Census Designated Places Labels',
#  'Census Designated Places',
#  'Incorporated Places Labels',
#  'Incorporated Places',
#  'Consolidated Cities Labels',
#  'Consolidated Cities',
#  'Subbarrios Labels',
#  'Subbarrios',
#  'County Subdivisions Labels',
#  'County Subdivisions',
#  'Estates Labels',
#  'Estates',
#  'Elementary School Districts Labels',
#  'Elementary School Districts',
#  'Secondary School Districts Labels',
#  'Secondary School Districts',
#  'Unified School Districts Labels',
#  'Unified School Districts',
#  '2020 Census Blocks Labels',
#  '2020 Census Blocks',
#  'Census Block Groups Labels',
#  'Census Block Groups',
#  'Census Tracts Labels',
#  'Census Tracts',
#  'Tribal Block Groups Labels',
#  'Tribal Block Groups',
#  'Tribal Census Tracts Labels',
#  'Tribal Census Tracts',
#  '2010 Census ZIP Code Tabulation Areas Labels',
#  '2010 Census ZIP Code Tabulation Areas',
#  '2010 Census Public Use Microdata Areas Labels',
#  '2010 Census Public Use Microdata Areas']

# %%
print(wms['States'].crsOptions)
print(wms['States'].styles)
print(wms['States'].boundingBoxWGS84)
# Out:
# ['EPSG:3857', 'EPSG:4326', 'EPSG:102100']
# {'default': {'title': 'States', 'legend': 'https://tigerweb.geo.census.gov/arcgis/services/TIGERweb/tigerWMS_Current/MapServer/WmsServer?request=GetLegendGraphic%26version=1.1.1%26format=image/png%26layer=States'}}
# (-179.999996, -67.301489, 179.999996, 88.920787)

# %%
[op.name for op in wms.operations]
# Out:
# ['GetCapabilities', 'GetMap', 'GetFeatureInfo', 'GetStyles']

# %%
wms.getOperationByName('GetMap').methods
# Out:
# [{'type': 'Get',
#   'url': 'https://tigerweb.geo.census.gov/arcgis/services/TIGERweb/tigerWMS_Current/MapServer/WmsServer?'}]

# %%
wms.getOperationByName('GetMap').formatOptions
# Out:
# ['image/bmp',
#  'image/jpeg',
#  'image/tiff',
#  'image/png',
#  'image/png8',
#  'image/png24',
#  'image/png32',
#  'image/gif',
#  'image/svg+xml']

# %%
img = wms.getmap(layers=['States'],
                 styles=['default'],
                 srs='EPSG:4326',
                 bbox=(-180, 10, -58, 80),
                 size=(600, 300),
                 format='image/jpeg',
                 transparent=True
)
out = open('state_test.jpg', 'wb')
out.write(img.read())
out.close()

from IPython.display import Image
Image(filename = 'state_test.jpg', width = 600, height = 300)

# %%
# Grid Generator Map Server
wms = WebMapService('https://recon.lccllc.info/ggms4326',
                    version='1.1.1')
print(wms.identification.type)
print(wms.identification.version)
print(wms.identification.title)
print(wms.identification.abstract)
img = wms.getmap(layers=['earth,grid'],
                 styles=['default'],
                 srs='EPSG:4326',
                 bbox=(-180, 50, -100, 80),
                 size=(600, 300),
                 format='image/jpeg',
                 transparent=True
)
out = open('grid_test.jpg', 'wb')
out.write(img.read())
out.close()

from IPython.display import Image
Image(filename = 'grid_test.jpg', width = 600, height = 300)
# Out:
# OGC:WMS
# 1.1.1
# Grid Gen WMS Server
# None

# %%
# Fairbanks 64.8378° N, 147.7164° W

# %%
# Grid Generator Map Server
wms = WebMapService('https://recon.lccllc.info/ggms4326',
                    version='1.1.1')
print(wms.identification.type)
print(wms.identification.version)
print(wms.identification.title)
print(wms.identification.abstract)
print(list(wms.contents))
img = wms.getmap(layers=['earth,grid'],
                 styles=['default'],
                 srs='EPSG:4326',
                 bbox=(-151, 59, -139, 71),
                 size=(600, 300),
                 format='image/jpeg',
                 transparent=True
)
out = open('fai_test.jpg', 'wb')
out.write(img.read())
out.close()

from IPython.display import Image
Image(filename = 'fai_test.jpg', width = 600, height = 300)
# Out:
# OGC:WMS
# 1.1.1
# Grid Gen WMS Server
# None
# ['ggms4326', 'earth', 'grid']
